# %% [markdown]
# <a href="https://colab.research.google.com/github/benjaminbrown038/deep-learning-own/blob/main/qwen_benchmark_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/benjaminbrown038/deep-learning-own.git
# Out:
# fatal: destination path 'deep-learning-own' already exists and is not an empty directory.

# %%
# %cd /content/deep-learning-own
# Out:
# /content/deep-learning-own

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 4), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 805 bytes | 402.00 KiB/s, done.
# From https://github.com/benjaminbrown038/deep-learning-own
#  * branch            main       -> FETCH_HEAD
#    9307ff1..47cd68f  main       -> origin/main
# Updating 9307ff1..47cd68f
# Fast-forward
#  qwen_benchmark.py | 23 +++++++++++++++++------
#  1 file changed, 17 insertions(+), 6 deletions(-)

# %%
# !python qwen_benchmark.py --help
# Out:
# usage: qwen_benchmark.py [-h] [--size {0.5B,1.5B,3B,7B,14B}] [--tokens TOKENS]
#                          [--context-tokens CONTEXT_TOKENS] [--prompt PROMPT]
#                          [--inspect-only]
#                          [--context-sweep CONTEXT_SWEEP [CONTEXT_SWEEP ...]]
#
# Benchmark one Qwen2.5 model.
#
# options:
#   -h, --help            show this help message and exit
#   --size {0.5B,1.5B,3B,7B,14B}
#   --tokens TOKENS
#   --context-tokens CONTEXT_TOKENS
#                         Number of tokens placed in the user prompt.
#   --prompt PROMPT
#   --inspect-only        Print model architecture without downloading model
#                         weights.
#   --context-sweep CONTEXT_SWEEP [CONTEXT_SWEEP ...]
#                         Test multiple context lengths, for example: 128 512
#                         1024

# %%
# !python qwen_benchmark.py \
  --size 1.5B \
  --context-sweep 128 512 1024 2048 \
  --tokens 50
# Out:
# ...
#
# 1.5B architecture
# --------------------------------
# Layers                   28
# Hidden Width             1,536
# Attention Heads          12
# Kv Heads                 2
# Head Dimension           128
# Mlp Width                8,960
# Vocabulary               151,936
# Rough Complexity Lxd2    66,060,288
#
# ...
# Context length: 128
# ...
#
# Loading: Qwen/Qwen2.5-1.5B-Instruct
# Accelerator: cuda
# Loading weights: 100% 338/338 [00:03<00:00, 109.60it/s]
#
# Results
# Parameters: 1,543,714,304
# Generated tokens: 50
# Time: 1.77 seconds
# Tokens/sec: 28.24
# Accelerator memory: 3.11 GB
#
# Response:
# A computer numerical control (CNC) machine is an automated tooling system that uses digital data to precisely control the movement of its various components. Here's a step-by-step explanation of how it works:
#
# 1. **Programming**: The first step in
#
# ...
# Context length: 512
# ...
#
# Loading: Qwen/Qwen2.5-1.5B-Instruct
# Accelerator: cuda
# ...
